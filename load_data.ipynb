# %%
import pandas as pd
from sqlalchemy import create_engine
from password import password

# %% [markdown]
# # Importing CSV's

# %%
y2001 = "Resource/y2001.csv"
y2001_df = pd.read_csv(y2001)
y2001_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude  PLNTCODE State
# 0       45.0  Hydroelectric  33.458665 -87.356823         2    AL
# 1      170.1    Natural Gas  31.006900 -88.010300         3    AL
# 2      191.8          Other  31.006900 -88.010300         3    AL
# 3      170.1    Natural Gas  31.006900 -88.010300         3    AL
# 4      170.1    Natural Gas  31.006900 -88.010300         3    AL

# %% [markdown]
# * Adding the Year to each row as separate column to prep for concatenation
# * Renaming all Plant code columns in each DataFrame into unviersal name: 'Plant_ID' for cleaner concatenation

# %%
y2001_df.rename(columns={'PLNTCODE': 'Plant_ID'}, inplace=True)

for row in y2001_df:
    y2001_df["Year"] = 2001
    
y2001_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude  Plant_ID State  Year
# 0       45.0  Hydroelectric  33.458665 -87.356823         2    AL  2001
# 1      170.1    Natural Gas  31.006900 -88.010300         3    AL  2001
# 2      191.8          Other  31.006900 -88.010300         3    AL  2001
# 3      170.1    Natural Gas  31.006900 -88.010300         3    AL  2001
# 4      170.1    Natural Gas  31.006900 -88.010300         3    AL  2001

# %%
y2002 = "Resource/y2002.csv"
y2002_df = pd.read_csv(y2002)
y2002_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude  PLNTCODE State
# 0       45.0  Hydroelectric  33.458665 -87.356823         2    AL
# 1      153.1           Coal  31.006900 -88.010300         3    AL
# 2      153.1           Coal  31.006900 -88.010300         3    AL
# 3      272.0           Coal  31.006900 -88.010300         3    AL
# 4      403.7           Coal  31.006900 -88.010300         3    AL

# %%
y2002_df.rename(columns={'PLNTCODE': 'Plant_ID'}, inplace=True)

for row in y2002_df:
    y2002_df["Year"] = 2002
    
y2002_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude  Plant_ID State  Year
# 0       45.0  Hydroelectric  33.458665 -87.356823         2    AL  2002
# 1      153.1           Coal  31.006900 -88.010300         3    AL  2002
# 2      153.1           Coal  31.006900 -88.010300         3    AL  2002
# 3      272.0           Coal  31.006900 -88.010300         3    AL  2002
# 4      403.7           Coal  31.006900 -88.010300         3    AL  2002

# %%
y2003 = "Resource/y2003.csv"
y2003_df = pd.read_csv(y2003)
y2003_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude  PLNTCODE State
# 0       45.0  Hydroelectric  33.458665 -87.356823         2    AL
# 1      153.1           Coal  31.006900 -88.010300         3    AL
# 2      153.1           Coal  31.006900 -88.010300         3    AL
# 3      272.0           Coal  31.006900 -88.010300         3    AL
# 4      403.7           Coal  31.006900 -88.010300         3    AL

# %%
y2003_df.rename(columns={'PLNTCODE': 'Plant_ID'}, inplace=True)

for row in y2003_df:
    y2003_df["Year"] = 2003
    
y2003_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude  Plant_ID State  Year
# 0       45.0  Hydroelectric  33.458665 -87.356823         2    AL  2003
# 1      153.1           Coal  31.006900 -88.010300         3    AL  2003
# 2      153.1           Coal  31.006900 -88.010300         3    AL  2003
# 3      272.0           Coal  31.006900 -88.010300         3    AL  2003
# 4      403.7           Coal  31.006900 -88.010300         3    AL  2003

# %%
y2004 = "Resource/y2004.csv"
y2004_df = pd.read_csv(y2004)
y2004_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude  PLNTCODE State
# 0       45.0  Hydroelectric  33.458665 -87.356823         2    AL
# 1      153.1           Coal  31.006900 -88.010300         3    AL
# 2      153.1           Coal  31.006900 -88.010300         3    AL
# 3      272.0           Coal  31.006900 -88.010300         3    AL
# 4      403.7           Coal  31.006900 -88.010300         3    AL

# %%
y2004_df.rename(columns={'PLNTCODE': 'Plant_ID'}, inplace=True)

for row in y2004_df:
    y2004_df["Year"] = 2004
    
y2004_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude  Plant_ID State  Year
# 0       45.0  Hydroelectric  33.458665 -87.356823         2    AL  2004
# 1      153.1           Coal  31.006900 -88.010300         3    AL  2004
# 2      153.1           Coal  31.006900 -88.010300         3    AL  2004
# 3      272.0           Coal  31.006900 -88.010300         3    AL  2004
# 4      403.7           Coal  31.006900 -88.010300         3    AL  2004

# %%
y2005 = "Resource/y2005.csv"
y2005_df = pd.read_csv(y2005)
y2005_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude  PLNTCODE State
# 0       45.0  Hydroelectric  33.458665 -87.356823         2    AL
# 1      153.1           Coal  31.006900 -88.010300         3    AL
# 2      153.1           Coal  31.006900 -88.010300         3    AL
# 3      272.0           Coal  31.006900 -88.010300         3    AL
# 4      403.7           Coal  31.006900 -88.010300         3    AL

# %%
y2005_df.rename(columns={'PLNTCODE': 'Plant_ID'}, inplace=True)

for row in y2005_df:
    y2005_df["Year"] = 2005
    
y2005_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude  Plant_ID State  Year
# 0       45.0  Hydroelectric  33.458665 -87.356823         2    AL  2005
# 1      153.1           Coal  31.006900 -88.010300         3    AL  2005
# 2      153.1           Coal  31.006900 -88.010300         3    AL  2005
# 3      272.0           Coal  31.006900 -88.010300         3    AL  2005
# 4      403.7           Coal  31.006900 -88.010300         3    AL  2005

# %%
y2006 = "Resource/y2006.csv"
y2006_df = pd.read_csv(y2006)
y2006_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude  PLNTCODE State
# 0       45.0  Hydroelectric  33.458665 -87.356823         2    AL
# 1      153.1           Coal  31.006900 -88.010300         3    AL
# 2      153.1           Coal  31.006900 -88.010300         3    AL
# 3      272.0           Coal  31.006900 -88.010300         3    AL
# 4      403.7           Coal  31.006900 -88.010300         3    AL

# %%
y2006_df.rename(columns={'PLNTCODE': 'Plant_ID'}, inplace=True)

for row in y2006_df:
    y2006_df["Year"] = 2006
    
y2006_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude  Plant_ID State  Year
# 0       45.0  Hydroelectric  33.458665 -87.356823         2    AL  2006
# 1      153.1           Coal  31.006900 -88.010300         3    AL  2006
# 2      153.1           Coal  31.006900 -88.010300         3    AL  2006
# 3      272.0           Coal  31.006900 -88.010300         3    AL  2006
# 4      403.7           Coal  31.006900 -88.010300         3    AL  2006

# %%
y2007 = "Resource/y2007.csv"
y2007_df = pd.read_csv(y2007)
y2007_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude  PLNTCODE State
# 0       45.0  Hydroelectric  33.458665 -87.356823         2    AL
# 1      153.1           Coal  31.006900 -88.010300         3    AL
# 2      153.1           Coal  31.006900 -88.010300         3    AL
# 3      272.0           Coal  31.006900 -88.010300         3    AL
# 4      403.7           Coal  31.006900 -88.010300         3    AL

# %%
y2007_df.rename(columns={'PLNTCODE': 'Plant_ID'}, inplace=True)

for row in y2007_df:
    y2007_df["Year"] = 2007
    
y2007_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude  Plant_ID State  Year
# 0       45.0  Hydroelectric  33.458665 -87.356823         2    AL  2007
# 1      153.1           Coal  31.006900 -88.010300         3    AL  2007
# 2      153.1           Coal  31.006900 -88.010300         3    AL  2007
# 3      272.0           Coal  31.006900 -88.010300         3    AL  2007
# 4      403.7           Coal  31.006900 -88.010300         3    AL  2007

# %%
y2008 = "Resource/y2008.csv"
y2008_df = pd.read_csv(y2008)
y2008_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude  PLNTCODE State
# 0       45.0  Hydroelectric  33.458665 -87.356823         2    AL
# 1      153.1           Coal  31.006900 -88.010300         3    AL
# 2      153.1           Coal  31.006900 -88.010300         3    AL
# 3      272.0           Coal  31.006900 -88.010300         3    AL
# 4      403.7           Coal  31.006900 -88.010300         3    AL

# %%
y2008_df.rename(columns={'PLNTCODE': 'Plant_ID'}, inplace=True)

for row in y2008_df:
    y2008_df["Year"] = 2008
    
y2008_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude  Plant_ID State  Year
# 0       45.0  Hydroelectric  33.458665 -87.356823         2    AL  2008
# 1      153.1           Coal  31.006900 -88.010300         3    AL  2008
# 2      153.1           Coal  31.006900 -88.010300         3    AL  2008
# 3      272.0           Coal  31.006900 -88.010300         3    AL  2008
# 4      403.7           Coal  31.006900 -88.010300         3    AL  2008

# %%
y2009 = "Resource/y2009.csv"
y2009_df = pd.read_csv(y2009)
y2009_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude  PLANT_CODE State
# 0       45.0  Hydroelectric  33.458665 -87.356823           2    AL
# 1      153.1           Coal  31.006900 -88.010300           3    AL
# 2      153.1           Coal  31.006900 -88.010300           3    AL
# 3      272.0           Coal  31.006900 -88.010300           3    AL
# 4      403.7           Coal  31.006900 -88.010300           3    AL

# %%
y2009_df.rename(columns={'PLANT_CODE': 'Plant_ID'}, inplace=True)

for row in y2009_df:
    y2009_df["Year"] = 2009
    
y2009_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude  Plant_ID State  Year
# 0       45.0  Hydroelectric  33.458665 -87.356823         2    AL  2009
# 1      153.1           Coal  31.006900 -88.010300         3    AL  2009
# 2      153.1           Coal  31.006900 -88.010300         3    AL  2009
# 3      272.0           Coal  31.006900 -88.010300         3    AL  2009
# 4      403.7           Coal  31.006900 -88.010300         3    AL  2009

# %%
y2010 = "Resource/y2010.csv"
y2010_df = pd.read_csv(y2010)
y2010_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude  PLANT_CODE State
# 0       45.0  Hydroelectric  33.458665 -87.356823           2    AL
# 1      153.1           Coal  31.006900 -88.010300           3    AL
# 2      153.1           Coal  31.006900 -88.010300           3    AL
# 3      272.0           Coal  31.006900 -88.010300           3    AL
# 4      403.7           Coal  31.006900 -88.010300           3    AL

# %%
y2010_df.rename(columns={'PLANT_CODE': 'Plant_ID'}, inplace=True)

for row in y2010_df:
    y2010_df["Year"] = 2010
    
y2010_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude  Plant_ID State  Year
# 0       45.0  Hydroelectric  33.458665 -87.356823         2    AL  2010
# 1      153.1           Coal  31.006900 -88.010300         3    AL  2010
# 2      153.1           Coal  31.006900 -88.010300         3    AL  2010
# 3      272.0           Coal  31.006900 -88.010300         3    AL  2010
# 4      403.7           Coal  31.006900 -88.010300         3    AL  2010

# %%
y2011 = "Resource/y2011.csv"
y2011_df = pd.read_csv(y2011)
y2011_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude  PLANT_CODE State
# 0       45.0  Hydroelectric  33.458665 -87.356823           2    AL
# 1      153.1           Coal  31.006900 -88.010300           3    AL
# 2      153.1           Coal  31.006900 -88.010300           3    AL
# 3      272.0           Coal  31.006900 -88.010300           3    AL
# 4      403.7           Coal  31.006900 -88.010300           3    AL

# %%
y2011_df.rename(columns={'PLANT_CODE': 'Plant_ID'}, inplace=True)

for row in y2011_df:
    y2011_df["Year"] = 2011
    
y2011_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude  Plant_ID State  Year
# 0       45.0  Hydroelectric  33.458665 -87.356823         2    AL  2011
# 1      153.1           Coal  31.006900 -88.010300         3    AL  2011
# 2      153.1           Coal  31.006900 -88.010300         3    AL  2011
# 3      272.0           Coal  31.006900 -88.010300         3    AL  2011
# 4      403.7           Coal  31.006900 -88.010300         3    AL  2011

# %%
y2012 = "Resource/y2012.csv"
y2012_df = pd.read_csv(y2012)
y2012_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude  Plant_ID State
# 0       45.0  Hydroelectric  33.458665 -87.356823         2    AL
# 1      153.1           Coal  31.006900 -88.010300         3    AL
# 2      153.1           Coal  31.006900 -88.010300         3    AL
# 3      272.0           Coal  31.006900 -88.010300         3    AL
# 4      403.7           Coal  31.006900 -88.010300         3    AL

# %%
for row in y2012_df:
    y2012_df["Year"] = 2012
    
y2012_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude  Plant_ID State  Year
# 0       45.0  Hydroelectric  33.458665 -87.356823         2    AL  2012
# 1      153.1           Coal  31.006900 -88.010300         3    AL  2012
# 2      153.1           Coal  31.006900 -88.010300         3    AL  2012
# 3      272.0           Coal  31.006900 -88.010300         3    AL  2012
# 4      403.7           Coal  31.006900 -88.010300         3    AL  2012

# %%
y2013 = "Resource/y2013.csv"
y2013_df = pd.read_csv(y2013)
y2013_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude  Plant_ID State
# 0       53.9  Hydroelectric  33.458665 -87.356823         2    AL
# 1      153.1           Coal  31.006900 -88.010300         3    AL
# 2      153.1           Coal  31.006900 -88.010300         3    AL
# 3      272.0           Coal  31.006900 -88.010300         3    AL
# 4      403.7           Coal  31.006900 -88.010300         3    AL

# %%
for row in y2013_df:
    y2013_df["Year"] = 2013
    
y2013_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude  Plant_ID State  Year
# 0       53.9  Hydroelectric  33.458665 -87.356823         2    AL  2013
# 1      153.1           Coal  31.006900 -88.010300         3    AL  2013
# 2      153.1           Coal  31.006900 -88.010300         3    AL  2013
# 3      272.0           Coal  31.006900 -88.010300         3    AL  2013
# 4      403.7           Coal  31.006900 -88.010300         3    AL  2013

# %%
y2014 = "Resource/y2014.csv"
y2014_df = pd.read_csv(y2014)
y2014_df.head()
# Out:
#    Nameplate Technology  Latitude  Longitude  Plant_ID State
# 0        2.3      Other   39.6740  -121.7300     57771    CA
# 1        1.0      Other   38.8403   -76.7764     55964    MD
# 2        1.0      Other   38.8403   -76.7764     55964    MD
# 3        1.0      Other   38.8403   -76.7764     55964    MD
# 4        1.0      Other   38.8403   -76.7764     55964    MD

# %%
for row in y2014_df:
    y2014_df["Year"] = 2014
    
y2014_df.head()
# Out:
#    Nameplate Technology  Latitude  Longitude  Plant_ID State  Year
# 0        2.3      Other   39.6740  -121.7300     57771    CA  2014
# 1        1.0      Other   38.8403   -76.7764     55964    MD  2014
# 2        1.0      Other   38.8403   -76.7764     55964    MD  2014
# 3        1.0      Other   38.8403   -76.7764     55964    MD  2014
# 4        1.0      Other   38.8403   -76.7764     55964    MD  2014

# %%
y2015 = "Resource/y2015.csv"
y2015_df = pd.read_csv(y2015)
y2015_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude  Plant_ID State
# 0       53.9  Hydroelectric  33.458665 -87.356823         2    AL
# 1      153.1    Natural Gas  31.006900 -88.010300         3    AL
# 2      153.1    Natural Gas  31.006900 -88.010300         3    AL
# 3      403.7           Coal  31.006900 -88.010300         3    AL
# 4      788.8           Coal  31.006900 -88.010300         3    AL

# %%
for row in y2015_df:
    y2015_df["Year"] = 2015
    
y2015_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude  Plant_ID State  Year
# 0       53.9  Hydroelectric  33.458665 -87.356823         2    AL  2015
# 1      153.1    Natural Gas  31.006900 -88.010300         3    AL  2015
# 2      153.1    Natural Gas  31.006900 -88.010300         3    AL  2015
# 3      403.7           Coal  31.006900 -88.010300         3    AL  2015
# 4      788.8           Coal  31.006900 -88.010300         3    AL  2015

# %%
y2016 = "Resource/y2016.csv"
y2016_df = pd.read_csv(y2016)
y2016_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude  Plant_ID State
# 0       53.9  Hydroelectric  33.458665 -87.356823         2    AL
# 1      153.1    Natural Gas  31.006900 -88.010300         3    AL
# 2      153.1    Natural Gas  31.006900 -88.010300         3    AL
# 3      403.7           Coal  31.006900 -88.010300         3    AL
# 4      788.8           Coal  31.006900 -88.010300         3    AL

# %%
for row in y2016_df:
    y2016_df["Year"] = 2016
    
y2016_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude  Plant_ID State  Year
# 0       53.9  Hydroelectric  33.458665 -87.356823         2    AL  2016
# 1      153.1    Natural Gas  31.006900 -88.010300         3    AL  2016
# 2      153.1    Natural Gas  31.006900 -88.010300         3    AL  2016
# 3      403.7           Coal  31.006900 -88.010300         3    AL  2016
# 4      788.8           Coal  31.006900 -88.010300         3    AL  2016

# %%
y2017 = "Resource/y2017.csv"
y2017_df = pd.read_csv(y2017)
y2017_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude  Plant_ID State
# 0       53.9  Hydroelectric  33.458665 -87.356823         2    AL
# 1      153.1    Natural Gas  31.006900 -88.010300         3    AL
# 2      153.1    Natural Gas  31.006900 -88.010300         3    AL
# 3      403.7           Coal  31.006900 -88.010300         3    AL
# 4      788.8           Coal  31.006900 -88.010300         3    AL

# %%
for row in y2017_df:
    y2017_df["Year"] = 2017
    
y2017_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude  Plant_ID State  Year
# 0       53.9  Hydroelectric  33.458665 -87.356823         2    AL  2017
# 1      153.1    Natural Gas  31.006900 -88.010300         3    AL  2017
# 2      153.1    Natural Gas  31.006900 -88.010300         3    AL  2017
# 3      403.7           Coal  31.006900 -88.010300         3    AL  2017
# 4      788.8           Coal  31.006900 -88.010300         3    AL  2017

# %%
y2018 = "Resource/y2018.csv"
y2018_df = pd.read_csv(y2018)
y2018_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude State  Plant_ID
# 0       53.9  Hydroelectric  33.458665 -87.356823    AL         2
# 1      153.1    Natural Gas  31.006900 -88.010300    AL         3
# 2      153.1    Natural Gas  31.006900 -88.010300    AL         3
# 3      403.7           Coal  31.006900 -88.010300    AL         3
# 4      788.8           Coal  31.006900 -88.010300    AL         3

# %%
for row in y2018_df:
    y2018_df["Year"] = 2018
    
y2018_df.head()
# Out:
#    Nameplate     Technology   Latitude  Longitude State  Plant_ID  Year
# 0       53.9  Hydroelectric  33.458665 -87.356823    AL         2  2018
# 1      153.1    Natural Gas  31.006900 -88.010300    AL         3  2018
# 2      153.1    Natural Gas  31.006900 -88.010300    AL         3  2018
# 3      403.7           Coal  31.006900 -88.010300    AL         3  2018
# 4      788.8           Coal  31.006900 -88.010300    AL         3  2018

# %% [markdown]
# # Concatenation

# %% [markdown]
# * Combining all Years into single DataFrame

# %%
frames = [y2001_df, y2002_df, y2003_df, y2004_df, y2005_df, y2006_df, y2007_df, y2008_df, y2009_df,
          y2010_df, y2011_df, y2012_df, y2013_df, y2014_df, y2015_df, y2016_df, y2017_df, y2018_df]
combined_df = pd.concat(frames, ignore_index=True)
combined_df
# Out:
#         Nameplate     Technology   Latitude  Longitude  Plant_ID State  Year
# 0            45.0  Hydroelectric  33.458665 -87.356823         2    AL  2001
# 1           170.1    Natural Gas  31.006900 -88.010300         3    AL  2001
# 2           191.8          Other  31.006900 -88.010300         3    AL  2001
# 3           170.1    Natural Gas  31.006900 -88.010300         3    AL  2001
# 4           170.1    Natural Gas  31.006900 -88.010300         3    AL  2001
# ...           ...            ...        ...        ...       ...   ...   ...
# 339802        1.1    Natural Gas  43.095340 -75.278357     62920    NY  2018
# 339803        1.1    Natural Gas  43.095340 -75.278357     62920    NY  2018
# 339804        0.3    Natural Gas  43.095340 -75.278357     62920    NY  2018
# 339805        6.0          Other  45.450000 -93.240000     62937    MN  2018
# 339806        5.0          Solar  30.494361 -81.600556     62940    FL  2018
#
# [339807 rows x 7 columns]

# %% [markdown]
# * Finding out the different energy types

# %%
combined_df['Technology'].value_counts()
# Out:
# Other            108073
# Natural Gas      104355
# Hydroelectric     75359
# Coal              24178
# Solar             13664
# Wind              12336
# Nuclear            1842
# Name: Technology, dtype: int64

# %% [markdown]
# * Separating all locations into different dataframes based on energy type

# %%
solar_df = combined_df.copy()
solar_df = solar_df.loc[solar_df['Technology'] == 'Solar']
solar_df
# Out:
#         Nameplate Technology   Latitude   Longitude  Plant_ID State  Year
# 264           0.2      Solar  33.422500 -111.912200       116    AZ  2001
# 265           0.1      Solar  33.422500 -111.912200       116    AZ  2001
# 266           0.1      Solar  33.422500 -111.912200       116    AZ  2001
# 304           0.2      Solar  33.556100 -112.215300       141    AZ  2001
# 1059          1.0      Solar  38.340015 -121.113861       529    CA  2001
# ...           ...        ...        ...         ...       ...   ...   ...
# 339796        4.5      Solar  40.053000  -74.556000     62905    NJ  2018
# 339797        2.9      Solar  41.099995  -74.731032     62906    NJ  2018
# 339799        1.0      Solar  39.149037  -77.317948     62910    MD  2018
# 339800        2.0      Solar  42.671105  -72.477491     62911    MA  2018
# 339806        5.0      Solar  30.494361  -81.600556     62940    FL  2018
#
# [13664 rows x 7 columns]

# %%
wind_df = combined_df.copy()
wind_df = wind_df.loc[wind_df['Technology'] == 'Wind']
wind_df
# Out:
#         Nameplate Technology   Latitude   Longitude  Plant_ID State  Year
# 1472          0.6       Wind  42.257200 -105.918100       692    WY  2001
# 1473          0.7       Wind  42.257200 -105.918100       692    WY  2001
# 1474          0.7       Wind  42.257200 -105.918100       692    WY  2001
# 1475          0.6       Wind  42.257200 -105.918100       692    WY  2001
# 1476          0.1       Wind  42.257200 -105.918100       692    WY  2001
# ...           ...        ...        ...         ...       ...   ...   ...
# 339695        2.5       Wind  33.591450 -102.056875     62642    TX  2018
# 339696        2.8       Wind  33.591450 -102.056875     62642    TX  2018
# 339765        0.3       Wind  43.226884  -77.361325     62736    NY  2018
# 339766        0.9       Wind  43.226884  -77.361325     62736    NY  2018
# 339776        1.0       Wind  48.996866  -97.241610     62782    ND  2018
#
# [12336 rows x 7 columns]

# %%
nuclear_df = combined_df.copy()
nuclear_df = nuclear_df.loc[nuclear_df['Technology'] == 'Nuclear']
nuclear_df
# Out:
#         Nameplate Technology  Latitude  Longitude  Plant_ID State  Year
# 83         1152.0    Nuclear  34.70420  -87.11890        46    AL  2001
# 84         1152.0    Nuclear  34.70420  -87.11890        46    AL  2001
# 85         1190.0    Nuclear  34.70420  -87.11890        46    AL  2001
# 437         990.0    Nuclear  40.17190  -88.83390       204    IL  2001
# 440        1235.7    Nuclear  38.23926  -95.68978       210    KS  2001
# ...           ...        ...       ...        ...       ...   ...   ...
# 326375      980.8    Nuclear  40.15150  -76.72320      8011    PA  2018
# 326425      801.0    Nuclear  40.36280  -95.64080      8036    NE  2018
# 326448      902.5    Nuclear  35.31100  -93.23510      8055    AR  2018
# 326449      942.5    Nuclear  35.31100  -93.23510      8055    AR  2018
# 326545     1012.0    Nuclear  41.27060  -73.95260      8907    NY  2018
#
# [1842 rows x 7 columns]

# %%
coal_df = combined_df.copy()
coal_df = coal_df.loc[coal_df['Technology'] == 'Coal']
coal_df
# Out:
#         Nameplate Technology   Latitude   Longitude  Plant_ID State  Year
# 6           153.1       Coal  31.006900  -88.010300         3    AL  2001
# 7           153.1       Coal  31.006900  -88.010300         3    AL  2001
# 8           272.0       Coal  31.006900  -88.010300         3    AL  2001
# 9           403.7       Coal  31.006900  -88.010300         3    AL  2001
# 10          788.8       Coal  31.006900  -88.010300         3    AL  2001
# ...           ...        ...        ...         ...       ...   ...   ...
# 334801        7.5       Coal  39.519989  -84.406153     57940    OH  2018
# 334815        1.5       Coal  43.741111  -83.447222     57949    MI  2018
# 334816        1.0       Coal  43.741111  -83.447222     57949    MI  2018
# 335000        3.0       Coal  40.263000 -103.806900     58081    CO  2018
# 339551        1.5       Coal  45.765346 -108.499232     62319    MT  2018
#
# [24178 rows x 7 columns]

# %%
hydroelectric_df = combined_df.copy()
hydroelectric_df = hydroelectric_df.loc[hydroelectric_df['Technology'] == 'Hydroelectric']
hydroelectric_df
# Out:
#         Nameplate     Technology   Latitude   Longitude  Plant_ID State  Year
# 0            45.0  Hydroelectric  33.458665  -87.356823         2    AL  2001
# 11           75.0  Hydroelectric  32.583889  -86.283056         4    AL  2001
# 12           75.0  Hydroelectric  32.583889  -86.283056         4    AL  2001
# 13           75.0  Hydroelectric  32.583889  -86.283056         4    AL  2001
# 33           24.3  Hydroelectric  33.784500  -86.052400        11    AL  2001
# ...           ...            ...        ...         ...       ...   ...   ...
# 339136        1.3  Hydroelectric  43.045100 -114.558800     61688    ID  2018
# 339291        6.5  Hydroelectric  40.596605 -111.423589     61853    UT  2018
# 339292        6.5  Hydroelectric  40.596605 -111.423589     61853    UT  2018
# 339553        2.0  Hydroelectric  42.876535  -73.680169     62322    NY  2018
# 339554        2.0  Hydroelectric  42.876535  -73.680169     62322    NY  2018
#
# [75359 rows x 7 columns]

# %%
naturalgas_df = combined_df.copy()
naturalgas_df = naturalgas_df.loc[naturalgas_df['Technology'] == 'Natural Gas']
naturalgas_df
# Out:
#         Nameplate   Technology   Latitude   Longitude  Plant_ID State  Year
# 1           170.1  Natural Gas  31.006900  -88.010300         3    AL  2001
# 3           170.1  Natural Gas  31.006900  -88.010300         3    AL  2001
# 4           170.1  Natural Gas  31.006900  -88.010300         3    AL  2001
# 21           80.5  Natural Gas  31.756900 -106.375000         9    TX  2001
# 22           80.0  Natural Gas  32.601700  -87.781100        10    AL  2001
# ...           ...          ...        ...         ...       ...   ...   ...
# 339792        1.0  Natural Gas  40.229379  -76.750070     62901    PA  2018
# 339801        1.1  Natural Gas  43.095340  -75.278357     62920    NY  2018
# 339802        1.1  Natural Gas  43.095340  -75.278357     62920    NY  2018
# 339803        1.1  Natural Gas  43.095340  -75.278357     62920    NY  2018
# 339804        0.3  Natural Gas  43.095340  -75.278357     62920    NY  2018
#
# [104355 rows x 7 columns]

# %%
other_df = combined_df.copy()
other_df = other_df.loc[other_df['Technology'] == 'Other']
other_df
# Out:
#         Nameplate Technology   Latitude   Longitude  Plant_ID State  Year
# 2           191.8      Other  31.006900  -88.010300         3    AL  2001
# 5           191.8      Other  31.006900  -88.010300         3    AL  2001
# 68           21.2      Other  33.244211  -86.458056        26    AL  2001
# 74            3.1      Other  44.052500  -94.415300        30    MN  2001
# 140           1.3      Other  58.310700 -134.417400        63    AK  2001
# ...           ...        ...        ...         ...       ...   ...   ...
# 339787        1.6      Other  44.908716  -72.221446     62859    VT  2018
# 339788        1.6      Other  44.908716  -72.221446     62859    VT  2018
# 339789        1.6      Other  44.908716  -72.221446     62859    VT  2018
# 339798        6.0      Other  45.320000  -93.480000     62908    MN  2018
# 339805        6.0      Other  45.450000  -93.240000     62937    MN  2018
#
# [108073 rows x 7 columns]

# %% [markdown]
# # Transformation
#
# * dropping any duplicate Plant_IDs

# %%
solar_df.drop_duplicates(subset=['Plant_ID'], inplace=True)
solar_df.set_index("Plant_ID", inplace=True)
solar_df
# Out:
#           Nameplate Technology   Latitude   Longitude State  Year
# Plant_ID
# 116             0.2      Solar  33.422500 -111.912200    AZ  2001
# 141             0.2      Solar  33.556100 -112.215300    AZ  2001
# 529             1.0      Solar  38.340015 -121.113861    CA  2001
# 3548            0.3      Solar  30.303300  -97.612800    TX  2001
# 7724            1.0      Solar  30.588219 -103.894696    TX  2001
# ...             ...        ...        ...         ...   ...   ...
# 62905           4.5      Solar  40.053000  -74.556000    NJ  2018
# 62906           2.9      Solar  41.099995  -74.731032    NJ  2018
# 62910           1.0      Solar  39.149037  -77.317948    MD  2018
# 62911           2.0      Solar  42.671105  -72.477491    MA  2018
# 62940           5.0      Solar  30.494361  -81.600556    FL  2018
#
# [2738 rows x 6 columns]

# %%
coal_df.drop_duplicates(subset=['Plant_ID'], inplace=True)
coal_df.set_index("Plant_ID", inplace=True)
coal_df
# Out:
#           Nameplate Technology   Latitude   Longitude State  Year
# Plant_ID
# 3             153.1       Coal  31.006900  -88.010300    AL  2001
# 7              69.0       Coal  34.012800  -85.970800    AL  2001
# 8             788.8       Coal  33.644344  -87.196486    AL  2001
# 10            299.2       Coal  32.601700  -87.781100    AL  2001
# 26            244.8       Coal  33.244211  -86.458056    AL  2001
# ...             ...        ...        ...         ...   ...   ...
# 58222           5.0       Coal  42.988611  -82.436667    MI  2012
# 56611        1008.0       Coal  31.474378  -96.957149    TX  2013
# 58923           0.5       Coal  37.953889  -91.774444    MO  2013
# 56786         106.2       Coal  46.926423  -98.499713    ND  2014
# 62319           1.5       Coal  45.765346 -108.499232    MT  2018
#
# [718 rows x 6 columns]

# %%
wind_df.drop_duplicates(subset=['Plant_ID'], inplace=True)
wind_df.set_index("Plant_ID", inplace=True)
wind_df
# Out:
#           Nameplate Technology   Latitude   Longitude State  Year
# Plant_ID
# 692             0.6       Wind  42.257200 -105.918100    WY  2001
# 7366            9.2       Wind  44.610800  -87.558600    WI  2001
# 7381            6.0       Wind  42.862500  -72.962800    VT  2001
# 7501            0.0       Wind  42.284150  -71.815214    MA  2001
# 7526            6.8       Wind  38.118300 -121.865300    CA  2001
# ...             ...        ...        ...         ...   ...   ...
# 62442           2.0       Wind  46.505052  -96.157281    MN  2018
# 62570           1.5       Wind  42.543748  -73.292632    MA  2018
# 62642           2.5       Wind  33.591450 -102.056875    TX  2018
# 62736           0.3       Wind  43.226884  -77.361325    NY  2018
# 62782           1.0       Wind  48.996866  -97.241610    ND  2018
#
# [1157 rows x 6 columns]

# %%
nuclear_df.drop_duplicates(subset=['Plant_ID'], inplace=True)
nuclear_df.set_index("Plant_ID", inplace=True)
nuclear_df
# Out:
#           Nameplate Technology   Latitude   Longitude State  Year
# Plant_ID
# 46           1152.0    Nuclear  34.704200  -87.118900    AL  2001
# 204           990.0    Nuclear  40.171900  -88.833900    IL  2001
# 210          1235.7    Nuclear  38.239260  -95.689780    KS  2001
# 360          1127.0    Nuclear  33.368794 -117.554916    CA  2001
# 371          1200.0    Nuclear  46.471100 -119.333900    WA  2001
# ...             ...        ...        ...         ...   ...   ...
# 8011          837.0    Nuclear  40.151500  -76.723200    PA  2001
# 8024          535.0    Nuclear  44.342200  -87.535800    WI  2001
# 8036          835.5    Nuclear  40.362800  -95.640800    NE  2001
# 8055          902.5    Nuclear  35.311000  -93.235100    AR  2001
# 8907         1012.0    Nuclear  41.270600  -73.952600    NY  2001
#
# [66 rows x 6 columns]

# %%
hydroelectric_df.drop_duplicates(subset=['Plant_ID'], inplace=True)
hydroelectric_df.set_index("Plant_ID", inplace=True)
hydroelectric_df
# Out:
#           Nameplate     Technology   Latitude   Longitude State  Year
# Plant_ID
# 2              45.0  Hydroelectric  33.458665  -87.356823    AL  2001
# 4              75.0  Hydroelectric  32.583889  -86.283056    AL  2001
# 11             24.3  Hydroelectric  33.784500  -86.052400    AL  2001
# 12             40.0  Hydroelectric  33.255300  -87.449500    AL  2001
# 13             25.0  Hydroelectric  32.618900  -86.254800    AL  2001
# ...             ...            ...        ...         ...   ...   ...
# 61853           6.5  Hydroelectric  40.596605 -111.423589    UT  2017
# 60418           6.0  Hydroelectric  47.600800 -121.688610    WA  2018
# 60517           6.0  Hydroelectric  47.572200 -121.689700    WA  2018
# 60868           1.2  Hydroelectric  45.370546 -121.756527    OR  2018
# 62322           2.0  Hydroelectric  42.876535  -73.680169    NY  2018
#
# [1555 rows x 6 columns]

# %%
naturalgas_df.drop_duplicates(subset=['Plant_ID'], inplace=True)
naturalgas_df.set_index("Plant_ID", inplace=True)
naturalgas_df
# Out:
#           Nameplate   Technology   Latitude   Longitude State  Year
# Plant_ID
# 3             170.1  Natural Gas  31.006900  -88.010300    AL  2001
# 9              80.5  Natural Gas  31.756900 -106.375000    TX  2001
# 10             80.0  Natural Gas  32.601700  -87.781100    AL  2001
# 30              2.0  Natural Gas  44.052500  -94.415300    MN  2001
# 47             59.5  Natural Gas  34.743900  -87.848600    AL  2001
# ...             ...          ...        ...         ...   ...   ...
# 62741           1.1  Natural Gas  40.108460  -76.476728    PA  2018
# 62757           1.5  Natural Gas  41.931838  -70.958393    MA  2018
# 62762           5.6  Natural Gas  29.562372  -95.089302    TX  2018
# 62901           1.0  Natural Gas  40.229379  -76.750070    PA  2018
# 62920           1.1  Natural Gas  43.095340  -75.278357    NY  2018
#
# [2568 rows x 6 columns]

# %%
other_df.drop_duplicates(subset=['Plant_ID'], inplace=True)
other_df.set_index("Plant_ID", inplace=True)
other_df
# Out:
#           Nameplate Technology   Latitude   Longitude State  Year
# Plant_ID
# 3             191.8      Other  31.006900  -88.010300    AL  2001
# 26             21.2      Other  33.244211  -86.458056    AL  2001
# 30              3.1      Other  44.052500  -94.415300    MN  2001
# 63              1.3      Other  58.310700 -134.417400    AK  2001
# 64              2.5      Other  58.353600 -134.495300    AK  2001
# ...             ...        ...        ...         ...   ...   ...
# 62733           5.0      Other  40.961751  -72.209858    NY  2018
# 62856          20.0      Other  42.252733  -88.639983    IL  2018
# 62859           1.6      Other  44.908716  -72.221446    VT  2018
# 62908           6.0      Other  45.320000  -93.480000    MN  2018
# 62937           6.0      Other  45.450000  -93.240000    MN  2018
#
# [3019 rows x 6 columns]

# %% [markdown]
# # Exporting Cleaned Data

# %%
combined_df.to_csv('Resource/Cleaned/combined.csv', index=False, header=True)

# %%
solar_df.to_csv('Resource/Cleaned/solar.csv', index=True, header=True)

# %%
wind_df.to_csv('Resource/Cleaned/wind.csv', index=True, header=True)

# %%
coal_df.to_csv('Resource/Cleaned/coal.csv', index=True, header=True)

# %%
nuclear_df.to_csv('Resource/Cleaned/nuclear.csv', index=True, header=True)

# %%
hydroelectric_df.to_csv('Resource/Cleaned/hydroelectric.csv', index=True, header=True)

# %%
naturalgas_df.to_csv('Resource/Cleaned/naturalgas.csv', index=True, header=True)

# %%
other_df.to_csv('Resource/Cleaned/other.csv', index=True, header=True)

# %% [markdown]
# # Exporting to SQL Database
#
# * Using sqlalchemy and Postgres to export all DataFrames into their own tables in a database

# %%
engine = create_engine(f'postgresql://postgres:{password}@localhost:5432/energy_db')

engine.table_names()
# Out:
# []

# %%
solar_df.to_sql(
    name = "solar",
    schema = 'public',
    con = engine,
    if_exists = 'append',
    index = True
    )

# %%
wind_df.to_sql(
    name = "wind",
    schema = 'public',
    con = engine,
    if_exists = 'append',
    index = True
    )

# %%
coal_df.to_sql(
    name = "coal",
    schema = 'public',
    con = engine,
    if_exists = 'append',
    index = True
    )

# %%
nuclear_df.to_sql(
    name = "nuclear",
    schema = 'public',
    con = engine,
    if_exists = 'append',
    index = True
    )

# %%
hydroelectric_df.to_sql(
    name = "hydroelectric",
    schema = 'public',
    con = engine,
    if_exists = 'append',
    index = True
    )

# %%
naturalgas_df.to_sql(
    name = "naturalgas",
    schema = 'public',
    con = engine,
    if_exists = 'append',
    index = True
    )

# %%
other_df.to_sql(
    name = "other",
    schema = 'public',
    con = engine,
    if_exists = 'append',
    index = True
    )
